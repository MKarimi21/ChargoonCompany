# %%
import pycaret as pc
import pandas as pd

# %%
sell_data = pd.read_excel('./HistoryOfSell_Rev02.xlsx', sheet_name='Sell')

sell_data.head()
# Out:
#         Date  A1  A2  A3  A4  A5  A6  A7  A8  A9  ...  A15  A16  A17  A18  \
# 0 2014-03-01   2   2   0   1   1   0   2   0   1  ...    0    0    1    0
# 1 2014-04-01   6   4   0   2   4   0   1   1   0  ...    0    1    0    2
# 2 2014-05-01   9   3   0   3   6   0   0   1   0  ...    0    0    2    0
# 3 2014-06-01   8   3   2   6   6   0   2   2   4  ...    0    0    2    0
# 4 2014-07-01  11   4   0   6   4   0   2   3   3  ...    0    0    2    0
#
#    A19  A20  A21  A22  A23  A24
# 0    1    0    1    1    0    0
# 1    6    3    5    5    2    2
# 2    4    1    3    1    0    0
# 3    6    2    6    3    0    0
# 4    9    0    6    5    0    0
#
# [5 rows x 25 columns]

# %%
sell_data['A3'].describe()
# Out:
# count    111.000000
# mean       2.567568
# std        2.258807
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.500000
# max       14.000000
# Name: A3, dtype: float64

# %%
import plotly.express as px


sell_data['A3_Mean'] = sell_data['A2'].rolling(12).mean()

fig = px.line(sell_data, x='Date', y=['A3', 'A3_Mean'], template='plotly_dark')
fig.show()

# %% [markdown]
# # A3

# %%
import numpy as np

# extract month and year from dates
sell_data['Month'] = [i.month for i in sell_data['Date']]
sell_data['Year'] = [i.year for i in sell_data['Date']]

# create a sequence of numbers
sell_data['Series'] = np.arange(1,len(sell_data)+1)

# drop unnecessary columns and re-arrange

sell_data.drop(['Date', 'A3_Mean'], axis=1, inplace=True)
sell_data = sell_data[['Series', 'Year', 'Month', 'A3']] 

# check the head of the dataset
sell_data.head()
# Out:
#    Series  Year  Month  A3
# 0       1  2014      3   0
# 1       2  2014      4   0
# 2       3  2014      5   0
# 3       4  2014      6   2
# 4       5  2014      7   0

# %%
# split data into train-test set
train = sell_data[sell_data['Year'] < 2022]
test = sell_data[sell_data['Year'] >= 2022]

# check shape
train.shape, test.shape
# Out:
# ((94, 4), (17, 4))

# %%
# import the regression module
from pycaret.regression import *

# initialize setup
s = setup(data = train, test_data = test, target = 'A3', fold_strategy = 'timeseries', numeric_features = ['Year', 'Series'], fold = 20, transform_target = True, session_id = 123)
# Out:
# <style type="text/css">
# #T_d502b_row8_col1, #T_d502b_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d502b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d502b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d502b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d502b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d502b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d502b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d502b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d502b_row1_col1" class="data row1 col1" >A3</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d502b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d502b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d502b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d502b_row3_col1" class="data row3 col1" >(111, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d502b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d502b_row4_col1" class="data row4 col1" >(111, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d502b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d502b_row5_col1" class="data row5 col1" >(94, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d502b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d502b_row6_col1" class="data row6 col1" >(17, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d502b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d502b_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d502b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d502b_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d502b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d502b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d502b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d502b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d502b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d502b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d502b_row12_col0" class="data row12 col0" >Transform target</td>
#       <td id="T_d502b_row12_col1" class="data row12 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d502b_row13_col0" class="data row13 col0" >Transform target method</td>
#       <td id="T_d502b_row13_col1" class="data row13 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d502b_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_d502b_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d502b_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_d502b_row15_col1" class="data row15 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d502b_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_d502b_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d502b_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_d502b_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d502b_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_d502b_row18_col1" class="data row18 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d502b_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_d502b_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d502b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d502b_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_d502b_row20_col1" class="data row20 col1" >f343</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(sort = 'MSE')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           17:48:37
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_5b9f3 th {
#   text-align: left;
# }
# #T_5b9f3_row0_col0, #T_5b9f3_row0_col1, #T_5b9f3_row0_col4, #T_5b9f3_row0_col5, #T_5b9f3_row0_col6, #T_5b9f3_row1_col0, #T_5b9f3_row1_col1, #T_5b9f3_row1_col2, #T_5b9f3_row1_col3, #T_5b9f3_row1_col4, #T_5b9f3_row1_col5, #T_5b9f3_row1_col6, #T_5b9f3_row2_col0, #T_5b9f3_row2_col1, #T_5b9f3_row2_col2, #T_5b9f3_row2_col3, #T_5b9f3_row2_col4, #T_5b9f3_row2_col5, #T_5b9f3_row2_col6, #T_5b9f3_row3_col0, #T_5b9f3_row3_col1, #T_5b9f3_row3_col2, #T_5b9f3_row3_col3, #T_5b9f3_row3_col4, #T_5b9f3_row3_col5, #T_5b9f3_row3_col6, #T_5b9f3_row4_col0, #T_5b9f3_row4_col2, #T_5b9f3_row4_col3, #T_5b9f3_row5_col0, #T_5b9f3_row5_col2, #T_5b9f3_row5_col3, #T_5b9f3_row6_col0, #T_5b9f3_row6_col1, #T_5b9f3_row6_col2, #T_5b9f3_row6_col3, #T_5b9f3_row6_col4, #T_5b9f3_row6_col5, #T_5b9f3_row6_col6, #T_5b9f3_row7_col0, #T_5b9f3_row7_col1, #T_5b9f3_row7_col2, #T_5b9f3_row7_col3, #T_5b9f3_row7_col4, #T_5b9f3_row7_col5, #T_5b9f3_row7_col6, #T_5b9f3_row8_col0, #T_5b9f3_row8_col1, #T_5b9f3_row8_col2, #T_5b9f3_row8_col3, #T_5b9f3_row8_col4, #T_5b9f3_row8_col5, #T_5b9f3_row8_col6, #T_5b9f3_row9_col0, #T_5b9f3_row9_col1, #T_5b9f3_row9_col2, #T_5b9f3_row9_col3, #T_5b9f3_row9_col4, #T_5b9f3_row9_col5, #T_5b9f3_row9_col6, #T_5b9f3_row10_col0, #T_5b9f3_row10_col1, #T_5b9f3_row10_col2, #T_5b9f3_row10_col3, #T_5b9f3_row10_col4, #T_5b9f3_row10_col5, #T_5b9f3_row10_col6, #T_5b9f3_row11_col0, #T_5b9f3_row11_col1, #T_5b9f3_row11_col2, #T_5b9f3_row11_col3, #T_5b9f3_row11_col4, #T_5b9f3_row11_col5, #T_5b9f3_row11_col6, #T_5b9f3_row12_col0, #T_5b9f3_row12_col1, #T_5b9f3_row12_col2, #T_5b9f3_row12_col3, #T_5b9f3_row12_col4, #T_5b9f3_row12_col5, #T_5b9f3_row12_col6, #T_5b9f3_row13_col0, #T_5b9f3_row13_col1, #T_5b9f3_row13_col2, #T_5b9f3_row13_col3, #T_5b9f3_row13_col4, #T_5b9f3_row13_col5, #T_5b9f3_row13_col6, #T_5b9f3_row14_col0, #T_5b9f3_row14_col1, #T_5b9f3_row14_col2, #T_5b9f3_row14_col3, #T_5b9f3_row14_col4, #T_5b9f3_row14_col5, #T_5b9f3_row14_col6, #T_5b9f3_row15_col0, #T_5b9f3_row15_col1, #T_5b9f3_row15_col2, #T_5b9f3_row15_col3, #T_5b9f3_row15_col4, #T_5b9f3_row15_col5, #T_5b9f3_row15_col6, #T_5b9f3_row16_col0, #T_5b9f3_row16_col1, #T_5b9f3_row16_col2, #T_5b9f3_row16_col3, #T_5b9f3_row16_col4, #T_5b9f3_row16_col5, #T_5b9f3_row16_col6, #T_5b9f3_row17_col0, #T_5b9f3_row17_col1, #T_5b9f3_row17_col2, #T_5b9f3_row17_col3, #T_5b9f3_row17_col4, #T_5b9f3_row17_col5, #T_5b9f3_row17_col6 {
#   text-align: left;
# }
# #T_5b9f3_row0_col2, #T_5b9f3_row0_col3, #T_5b9f3_row4_col1, #T_5b9f3_row4_col4, #T_5b9f3_row4_col5, #T_5b9f3_row4_col6, #T_5b9f3_row5_col1, #T_5b9f3_row5_col4, #T_5b9f3_row5_col5, #T_5b9f3_row5_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5b9f3_row0_col7, #T_5b9f3_row1_col7, #T_5b9f3_row2_col7, #T_5b9f3_row3_col7, #T_5b9f3_row4_col7, #T_5b9f3_row5_col7, #T_5b9f3_row6_col7, #T_5b9f3_row7_col7, #T_5b9f3_row8_col7, #T_5b9f3_row9_col7, #T_5b9f3_row10_col7, #T_5b9f3_row11_col7, #T_5b9f3_row12_col7, #T_5b9f3_row13_col7, #T_5b9f3_row14_col7, #T_5b9f3_row15_col7, #T_5b9f3_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5b9f3_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5b9f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b9f3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5b9f3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5b9f3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5b9f3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5b9f3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5b9f3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5b9f3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5b9f3_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b9f3_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_5b9f3_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_5b9f3_row0_col1" class="data row0 col1" >1.5949</td>
#       <td id="T_5b9f3_row0_col2" class="data row0 col2" >5.6626</td>
#       <td id="T_5b9f3_row0_col3" class="data row0 col3" >2.0858</td>
#       <td id="T_5b9f3_row0_col4" class="data row0 col4" >-0.6578</td>
#       <td id="T_5b9f3_row0_col5" class="data row0 col5" >0.5919</td>
#       <td id="T_5b9f3_row0_col6" class="data row0 col6" >0.4749</td>
#       <td id="T_5b9f3_row0_col7" class="data row0 col7" >0.1350</td>
#     </tr>
#     <tr>
#       <th id="T_5b9f3_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_5b9f3_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_5b9f3_row1_col1" class="data row1 col1" >1.5871</td>
#       <td id="T_5b9f3_row1_col2" class="data row1 col2" >5.8123</td>
#       <td id="T_5b9f3_row1_col3" class="data row1 col3" >2.0862</td>
#       <td id="T_5b9f3_row1_col4" class="data row1 col4" >-1.0594</td>
#       <td id="T_5b9f3_row1_col5" class="data row1 col5" >0.5858</td>
#       <td id="T_5b9f3_row1_col6" class="data row1 col6" >0.4662</td>
#       <td id="T_5b9f3_row1_col7" class="data row1 col7" >0.2380</td>
#     </tr>
#     <tr>
#       <th id="T_5b9f3_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_5b9f3_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_5b9f3_row2_col1" class="data row2 col1" >1.5951</td>
#       <td id="T_5b9f3_row2_col2" class="data row2 col2" >5.9052</td>
#       <td id="T_5b9f3_row2_col3" class="data row2 col3" >2.1000</td>
#       <td id="T_5b9f3_row2_col4" class="data row2 col4" >-0.5184</td>
#       <td id="T_5b9f3_row2_col5" class="data row2 col5" >0.5909</td>
#       <td id="T_5b9f3_row2_col6" class="data row2 col6" >0.4897</td>
#       <td id="T_5b9f3_row2_col7" class="data row2 col7" >0.1370</td>
#     </tr>
#     <tr>
#       <th id="T_5b9f3_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_5b9f3_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_5b9f3_row3_col1" class="data row3 col1" >1.6703</td>
#       <td id="T_5b9f3_row3_col2" class="data row3 col2" >6.1110</td>
#       <td id="T_5b9f3_row3_col3" class="data row3 col3" >2.1528</td>
#       <td id="T_5b9f3_row3_col4" class="data row3 col4" >-0.6263</td>
#       <td id="T_5b9f3_row3_col5" class="data row3 col5" >0.6113</td>
#       <td id="T_5b9f3_row3_col6" class="data row3 col6" >0.5614</td>
#       <td id="T_5b9f3_row3_col7" class="data row3 col7" >0.1380</td>
#     </tr>
#     <tr>
#       <th id="T_5b9f3_level0_row4" class="row_heading level0 row4" >dummy</th>
#       <td id="T_5b9f3_row4_col0" class="data row4 col0" >Dummy Regressor</td>
#       <td id="T_5b9f3_row4_col1" class="data row4 col1" >1.5791</td>
#       <td id="T_5b9f3_row4_col2" class="data row4 col2" >6.1156</td>
#       <td id="T_5b9f3_row4_col3" class="data row4 col3" >2.1225</td>
#       <td id="T_5b9f3_row4_col4" class="data row4 col4" >-0.4723</td>
#       <td id="T_5b9f3_row4_col5" class="data row4 col5" >0.5813</td>
#       <td id="T_5b9f3_row4_col6" class="data row4 col6" >0.4474</td>
#       <td id="T_5b9f3_row4_col7" class="data row4 col7" >0.1775</td>
#     </tr>
#     <tr>
#       <th id="T_5b9f3_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_5b9f3_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_5b9f3_row5_col1" class="data row5 col1" >1.5791</td>
#       <td id="T_5b9f3_row5_col2" class="data row5 col2" >6.1156</td>
#       <td id="T_5b9f3_row5_col3" class="data row5 col3" >2.1225</td>
#       <td id="T_5b9f3_row5_col4" class="data row5 col4" >-0.4723</td>
#       <td id="T_5b9f3_row5_col5" class="data row5 col5" >0.5813</td>
#       <td id="T_5b9f3_row5_col6" class="data row5 col6" >0.4474</td>
#       <td id="T_5b9f3_row5_col7" class="data row5 col7" >0.1410</td>
#     </tr>
#     <tr>
#       <th id="T_5b9f3_level0_row6" class="row_heading le
# Processing:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
prediction_holdout = predict_model(best);

# %%
# generate predictions on the original dataset**
predictions = predict_model(best, data=sell_data)

# add a date column in the dataset**
predictions['Date'] = pd.date_range(start='2014-03-01', end = '2023-05-01', freq = 'MS')

# line plot**
fig = px.line(predictions, x='Date', y=["A3", "prediction_label"], template = 'plotly_dark')

# add a vertical rectange for test-set separation**
fig.add_vrect(x0="2022-07-01", x1="2023-06-01", fillcolor="grey", opacity=0.25, line_width=0)

fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_6fa94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fa94_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6fa94_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6fa94_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6fa94_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6fa94_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6fa94_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6fa94_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fa94_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fa94_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_6fa94_row0_col1" class="data row0 col1" >1.5110</td>
#       <td id="T_6fa94_row0_col2" class="data row0 col2" >4.8208</td>
#       <td id="T_6fa94_row0_col3" class="data row0 col3" >2.1956</td>
#       <td id="T_6fa94_row0_col4" class="data row0 col4" >0.0466</td>
#       <td id="T_6fa94_row0_col5" class="data row0 col5" >0.5702</td>
#       <td id="T_6fa94_row0_col6" class="data row0 col6" >0.4860</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions
# Out:
#      Series  Year  Month        A3  prediction_label       Date
# 0         1  2014      3  0.000000          0.256472 2014-03-01
# 1         2  2014      4  0.000000          0.256472 2014-04-01
# 2         3  2014      5  0.000000          0.256472 2014-05-01
# 3         4  2014      6  1.152985          0.444188 2014-06-01
# 4         5  2014      7  0.000000          0.657177 2014-07-01
# ..      ...   ...    ...       ...               ...        ...
# 106     107  2023      1  0.714534          1.769477 2023-01-01
# 107     108  2023      2  1.152985          1.769477 2023-02-01
# 108     109  2023      3  0.714534          1.769477 2023-03-01
# 109     110  2023      4  0.000000          1.769477 2023-04-01
# 110     111  2023      5  2.120845          1.769477 2023-05-01
#
# [111 rows x 6 columns]

# %%
final_best = finalize_model(best)

# %%
future_dates = pd.date_range(start = '2023-06-01', end = '2024-05-01', freq = 'MS')

future_df = pd.DataFrame()

future_df['Month'] = [i.month for i in future_dates]
future_df['Year'] = [i.year for i in future_dates]    
future_df['Series'] = np.arange(112,(112+len(future_dates)))

future_df.head()
# Out:
#    Month  Year  Series
# 0      6  2023     112
# 1      7  2023     113
# 2      8  2023     114
# 3      9  2023     115
# 4     10  2023     116

# %%
predictions_future = predict_model(final_best, data=future_df)
predictions_future.head()
# Out:
#    Month  Year  Series  prediction_label
# 0      6  2023     112          1.486762
# 1      7  2023     113          1.486762
# 2      8  2023     114          1.859492
# 3      9  2023     115          1.859492
# 4     10  2023     116          1.318885

# %%
concat_df = pd.concat([sell_data, predictions_future], axis=0)
concat_df_i = pd.date_range(start='2014-03-01', end = '2024-05-01', freq = 'MS')
concat_df.set_index(concat_df_i, inplace=True)

fig = px.line(concat_df, x=concat_df.index, y=["A3", "prediction_label"], template = 'plotly_dark')
fig.show()
