# %% [markdown]
# <div>
#     <h1 style="text-align:center; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:14pt; font-weight: 900;">
#     تیم اول؛ پشتیبانی نرم‌افزار
#     </h1>
#     <p style="text-align:center; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:13pt; line-height:2;">
#         <span style="font-weight:700;">تعریف شاخص‌های کلیدی عملکرد برای شرکت چارگون </span>
#     <br>
#         <span style="font-weight:700;"> تدوین:</span> مصطفی کریمی
#     <br>
#         <span style="font-weight:700;">کنترل:</span> مهدی عامری
#     <br>
#         <span style="color: #646464; font-size:11pt;">نسخه اول - ویرایش اول - تاریخ ۱۴۰۲/۰۴/۰۳ </span>
#     </p>
# </div>
#
#
#
# <p style="text-align:center;">
#     <a href="https://wakatime.com/badge/user/77c38c6e-61da-47be-8032-3396542aff6d/project/9d7b8c7d-6848-4ddc-a51c-c1fba9e5160e" target="_blank"><img src="https://wakatime.com/badge/user/77c38c6e-61da-47be-8032-3396542aff6d/project/9d7b8c7d-6848-4ddc-a51c-c1fba9e5160e.svg" alt="wakatime"></a> &nbsp;
#     <a href="https://wakatime.com/@mkarimi21/projects/icxncnrgsb"><img src="https://badgen.net/static/Repo/Dashboard/red?icon=graphql&label/" alt="wakatim_dashboard" target="_blank"></a>
# </p>

# %% [markdown]
# <div dir="rtl">
#     <h2 style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:14pt; font-weight:700;">
#     شاخص‌های علمکردی برای تیم پشتیبانی نرم‌افزار
#     </h2>
# </div>

# %% [markdown]
# <p style="text-align:center;">
#     <img src="https://user-images.githubusercontent.com/85065799/204543278-26c507b6-400a-42e0-852f-2e09362f6e12.png" alt="Line" target="_blank">
# </p>

# %% [markdown]
# <div dir="rtl">
#     <h3 style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:14pt; font-weight:700;">
#         ۱. زمان پاسخ‌دهی به درخواست‌ها
#     </h3>
# </div>
#
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:13pt; line-height:2;">
#         <b>هدف:</b> کاهش زمان پاسخ‌دهی به درخواست‌های مشتریان
#     </p>
# </div>
#
#
#
#
# <div dir="rtl">
#     <div align="center">
#         <table style="width:90%; border:3px solid black; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt;">
#             <tr style="text-align:center; line-height: 2;">
#                 <th> ورودی </th>
#                 <th> معیار اندازه گیری </th>
#                 <th> منبع داده </th>
#                 <th> بازه زمانی </th>
#                 <th> خروجی </th>
#             </tr>
#             <tr>
#                 <td style="text-align:right; padding-right:20px; line-height: 2;">
#                     <li> زمان پاسخ‌دهی به هر درخواست (به واحد دقیقه) </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> میانگین زمان پاسخ‌دهی به درخواست‌ها </li>
#                 </td >
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> سیستم پشتیبانی نرم‌افزار </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> ماهیانه </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> میانگین زمان پاسخ‌دهی به درخواست‌ها </li>
#                 </td>
#             </tr>
#         </table>
#     </div>
# </div>
#
# <br><br>
#
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         <b>فرمول ریاضی</b> <br>
#         <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> میانگین زمان پاسخ‌دهی به درخواست‌ها</span><br>
#     </p>
# </div>
#
#
# $$Average\ of\ Requests = \frac{\sum_{n=1}^{N}\ Requests}{N}$$
#
#
# <br><br>
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         <b>کد پایتون:</b> <br>
#     </p>
# </div>
# <br>
#
# ``` python
# def calculate_response_time(requests):
#     total_time = sum(requests)  # جمع زمان پاسخ‌دهی به درخواست‌ها
#     avg_time = total_time / len(requests)  # میانگین زمان پاسخ‌دهی
#     return avg_time
#
# ```
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         سوالات مرتبط با شاخص
#     </p>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۱. نتیجه‌ای که می‌خواهید به‌دست آورید، چیست؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۲. چرا این نتیجه مهم است؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۳. چگونه می‌توانید بر این نتیجه تأثیر بگذارید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۴. چه کسی مسئول نتیجه است؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۵. چگونه می‌خواهید پیشرفت را با نتیجه گفته‌شده اندازه‌گیری کنید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۶. چگونه می‌دانید که به نتیجه رسیده‌اید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۷. هر چند وقت یک بار پیشرفت خود را با نتیجه بررسی می‌کنید؟</span><br>
# </div>
#
# <br><br>
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         OKRهای مرتبط برای شاخص‌ها
#     </p>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> <b> هدف: </b> کاهش زمان پاسخ‌دهی به درخواست‌ها به زیر ۲ ساعت تا پایان سه ماه بعد </span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> اهداف گروهی: </b><br>
#         <span style="padding-right:30px;">
#          ۱. افزایش کارایی فرآیند پاسخ‌دهی به درخواست‌ها
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. بهبود فرآیند ارتباط با مشتریان و درک بهتر نیازهای آن
#         </span>
#     </span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> نتایج کلیدی: </b> <br>
#         <span style="padding-right:30px;">
#         ۱. کاهش میانگین زمان پاسخ‌دهی به درخواست‌ها به زیر ۲ ساعت
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. افزایش به ۹۵ درصد درخواست‌های پاسخ‌دهی شده در محدوده زمانی مشخص
#         </span><br>
#     </span>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> اقدامات: </b> <br>
#         <span style="padding-right:30px;">
#         ۱. آموزش کارکنان درباره فنون و مهارت‌های ارتباطی و رضایتمندی مشتریان
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. افزایش به ۹۵ درصد درخواست‌های پاسخ‌دهی شده در محدوده زمانی مشخص
#         </span><br>
#         <span style="padding-right:30px;">
#         ۳. برنامه‌ریزی و تخصیص منابع بهینه برای پاسخ‌دهی سریع به درخواست‌ها
#         </span>
#     </span><br>
# </div>

# %% [markdown]
# <p style="text-align:center;">
#     <img src="https://user-images.githubusercontent.com/85065799/204543278-26c507b6-400a-42e0-852f-2e09362f6e12.png" alt="Line" target="_blank">
# </p>

# %% [markdown]
# <div dir="rtl">
#     <h3 style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:14pt; font-weight:700;">
#     ۲. میزان رضایتمندی مشتریان
#     </h3>
# </div>
#
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:13pt; line-height:2;">
#         <b>هدف:</b> افزایش رضایتمندی مشتریان
#     </p>
# </div>
#
#
#
#
# <div dir="rtl">
#     <div align="center">
#         <table style="width:90%; border:3px solid black; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt;">
#             <tr style="text-align:center; line-height: 2;">
#                 <th> ورودی </th>
#                 <th> معیار اندازه گیری </th>
#                 <th> منبع داده </th>
#                 <th> بازه زمانی </th>
#                 <th> خروجی </th>
#             </tr>
#             <tr>
#                 <td style="text-align:right; padding-right:20px; line-height: 2;">
#                     <li> نمره رضایتمندی مشتریان (از ۱۰) </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> میانگین نمره رضایتمندی مشتریان </li>
#                 </td >
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> نظرسنجی‌ها و بازخوردهای مشتری </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> ماهیانه </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> میانگین نمره رضایتمندی مشتریان </li>
#                 </td>
#             </tr>
#         </table>
#     </div>
# </div>
#
# <br><br>
#
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         <b>فرمول ریاضی</b> <br>
#         <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> میانگین نمره رضایتمندی مشتریان </span><br>
#     </p>
# </div>
#
# $$Average\ of\ Vote = \frac{\sum_{n=1}^{N}\ Vote}{N}$$
#
# <br><br>
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         <b>کد پایتون:</b> <br>
#     </p>
# </div>
# <br>
#
# ``` python
# def calculate_customer_satisfaction(scores):
#     total_score = sum(scores)  # جمع نمرات رضایتمندی
#     avg_score = total_score / len(scores)  # میانگین نمره رضایتمندی
#     return avg_score
#
# ```
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         سوالات مرتبط با شاخص
#     </p>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۱. نتیجه‌ای که می‌خواهید به‌دست آورید، چیست؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۲. چرا این نتیجه مهم است؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۳. چگونه می‌توانید بر این نتیجه تأثیر بگذارید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۴. چه کسی مسئول نتیجه است؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۵. چگونه می‌خواهید پیشرفت را با نتیجه گفته‌شده اندازه‌گیری کنید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۶. چگونه می‌دانید که به نتیجه رسیده‌اید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۷. هر چند وقت یک بار پیشرفت خود را با نتیجه بررسی می‌کنید؟</span><br>
# </div>
#
# <br><br>
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         OKRهای مرتبط برای شاخص‌ها
#     </p>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> <b> هدف: </b> افزایش نمره رضایتمندی مشتریان از ۸.۵ به ۹.۵ تا پایان سه ماه بعد </span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> اهداف گروهی: </b><br>
#         <span style="padding-right:30px;">
#          ۱. بهبود فرآیند ارتباط با مشتریان و بهبود تجربه آن‌ها
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. افزایش پاسخگویی به نیازها و مشکلات مشتریان
#         </span>
#     </span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> نتایج کلیدی: </b> <br>
#         <span style="padding-right:30px;">
#         ۱. افزایش میانگین نمره رضایتمندی مشتریان از ۸.۵ به ۹.۵
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. افزایش درصد مشتریان راضی به بالای ۹۰ درصد
#         </span><br>
#     </span>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> اقدامات: </b> <br>
#         <span style="padding-right:30px;">
#         ۱. ایجاد سیستم فیدبک و بررسی مشکلات مشتریان به منظور بهبود عملکرد و خدمات
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. برگزاری جلسات وبینارها برای آموزش کارکنان در خصوص خدمات بهتر به مشتریان
#         </span><br>
#     </span><br>
# </div>

# %% [markdown]
# <p style="text-align:center;">
#     <img src="https://user-images.githubusercontent.com/85065799/204543278-26c507b6-400a-42e0-852f-2e09362f6e12.png" alt="Line" target="_blank">
# </p>

# %% [markdown]
# <div dir="rtl">
#     <h3 style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:14pt; font-weight:700;">
#     ۲. میزان رضایتمندی مشتریان
#     </h3>
# </div>
#
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:13pt; line-height:2;">
#         <b>هدف:</b> افزایش رضایتمندی مشتریان
#     </p>
# </div>
#
#
#
#
# <div dir="rtl">
#     <div align="center">
#         <table style="width:90%; border:3px solid black; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt;">
#             <tr style="text-align:center; line-height: 2;">
#                 <th> ورودی </th>
#                 <th> معیار اندازه گیری </th>
#                 <th> منبع داده </th>
#                 <th> بازه زمانی </th>
#                 <th> خروجی </th>
#             </tr>
#             <tr>
#                 <td style="text-align:right; padding-right:20px; line-height: 2;">
#                     <li> نمره رضایتمندی مشتریان (از ۱۰) </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> میانگین نمره رضایتمندی مشتریان </li>
#                 </td >
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> نظرسنجی‌ها و بازخوردهای مشتری </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> ماهیانه </li>
#                 </td>
#                 <td style="padding-right:20px; text-align:right; line-height: 2;">
#                     <li> میانگین نمره رضایتمندی مشتریان </li>
#                 </td>
#             </tr>
#         </table>
#     </div>
# </div>
#
# <br><br>
#
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         <b>فرمول ریاضی</b> <br>
#         <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> میانگین نمره رضایتمندی مشتریان </span><br>
#     </p>
# </div>
#
# $$Average\ of\ Vote = \frac{\sum_{n=1}^{N}\ Vote}{N}$$
#
# <br><br>
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         <b>کد پایتون:</b> <br>
#     </p>
# </div>
# <br>
#
# ``` python
# def calculate_customer_satisfaction(scores):
#     total_score = sum(scores)  # جمع نمرات رضایتمندی
#     avg_score = total_score / len(scores)  # میانگین نمره رضایتمندی
#     return avg_score
#
# ```
#
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         سوالات مرتبط با شاخص
#     </p>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۱. نتیجه‌ای که می‌خواهید به‌دست آورید، چیست؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۲. چرا این نتیجه مهم است؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۳. چگونه می‌توانید بر این نتیجه تأثیر بگذارید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۴. چه کسی مسئول نتیجه است؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۵. چگونه می‌خواهید پیشرفت را با نتیجه گفته‌شده اندازه‌گیری کنید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۶. چگونه می‌دانید که به نتیجه رسیده‌اید؟</span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> ۷. هر چند وقت یک بار پیشرفت خود را با نتیجه بررسی می‌کنید؟</span><br>
# </div>
#
# <br><br>
#
# <div dir="rtl">
#     <p style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; padding-right:10px;">
#         OKRهای مرتبط برای شاخص‌ها
#     </p>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;"> <b> هدف: </b> افزایش نمره رضایتمندی مشتریان از ۸.۵ به ۹.۵ تا پایان سه ماه بعد </span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> اهداف گروهی: </b><br>
#         <span style="padding-right:30px;">
#          ۱. بهبود فرآیند ارتباط با مشتریان و بهبود تجربه آن‌ها
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. افزایش پاسخگویی به نیازها و مشکلات مشتریان
#         </span>
#     </span><br>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> نتایج کلیدی: </b> <br>
#         <span style="padding-right:30px;">
#         ۱. افزایش میانگین نمره رضایتمندی مشتریان از ۸.۵ به ۹.۵
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. افزایش درصد مشتریان راضی به بالای ۹۰ درصد
#         </span><br>
#     </span>
#     <span style="text-align:right; font-family: Vazirmatn, B Nazanin, Tahoma; font-size:11pt; line-height:2; color: #656565; padding-right:20px;">
#         <b> اقدامات: </b> <br>
#         <span style="padding-right:30px;">
#         ۱. ایجاد سیستم فیدبک و بررسی مشکلات مشتریان به منظور بهبود عملکرد و خدمات
#         </span><br>
#         <span style="padding-right:30px;">
#         ۲. برگزاری جلسات وبینارها برای آموزش کارکنان در خصوص خدمات بهتر به مشتریان
#         </span><br>
#     </span><br>
# </div>

# %% [markdown]
# <p style="text-align:center;">
#     <img src="https://user-images.githubusercontent.com/85065799/204543278-26c507b6-400a-42e0-852f-2e09362f6e12.png" alt="Line" target="_blank">
# </p>
